# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df= application_df.drop('EIN', axis=1)
application_df= application_df.drop('NAME', axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9','T13', 'T12','T2','T25','T14','T29','T15','T17']
    


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C2190        1
# C3700        1
# C1248        1
# C2380        1
# C2500        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C4100        6
# C2400        6
# C1720        6
# C1600        5
# C1257        5
# C0           3
# C2710        3
# C1260        3
# C1267        2
# C1256        2
# C1246        2
# C1234        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
#finding those below 100
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x<100]
# Out:
# C2800    95
# C7100    75
# C1300    58
# C1280    50
# C1230    36
# C1400    34
# C2300    32
# C7200    32
# C1240    30
# C8000    20
# C7120    18
# C1500    16
# C1800    15
# C6000    15
# C1250    14
# C8200    11
# C1238    10
# C1278    10
# C1235     9
# C1237     9
# C7210     7
# C4100     6
# C2400     6
# C1720     6
# C1600     5
# C1257     5
# C0        3
# C2710     3
# C1260     3
# C1267     2
# C1256     2
# C1246     2
# C1234     2
# C3200     2
# C1732     1
# C5200     1
# C1728     1
# C2600     1
# C4120     1
# C1283     1
# C1245     1
# C1370     1
# C2561     1
# C8210     1
# C1900     1
# C2170     1
# C4500     1
# C1580     1
# C1236     1
# C2570     1
# C4200     1
# C1570     1
# C6100     1
# C2150     1
# C1820     1
# C2190     1
# C3700     1
# C1248     1
# C2380     1
# C2500     1
# Name: CLASSIFICATION, dtype: int64

# %%
#finding those below 1800
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x<1800]
# Out:
# C7000    777
# C1700    287
# C4000    194
# C5000    116
# C1270    114
#         ...
# C2190      1
# C3700      1
# C1248      1
# C2380      1
# C2500      1
# Name: CLASSIFICATION, Length: 66, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace=['C2800','C7100','C1300','C1280','C1230','C1400','C2300','C7200','C1240',
                            'C8000','C7120','C1500','C6000','C1800','C1250','C8200','C1278','C1238',
                            'C1235','C1237','C7210','C1720','C4100','C2400','C1257','C1600','C2710',
                            'C1260','C0','C1234','C3200','C1256','C1267','C1246','C2561','C8210',
                            'C4500','C2380','C1370','C1728','C1732','C1900','C6100','C1245','C1570',
                            'C1248','C4200','C3700','C1820','C2190','C1580','C2570','C4120','C2500',
                            'C2150','C2600','C2170','C1283','C5200','C1236','C7000','C1700','C4000','C5000',
                            'C1270','C2700']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df_dummy = pd.get_dummies(application_df)
df_dummy.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
target = df_dummy['IS_SUCCESSFUL']
features = df_dummy.drop(columns=['IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# __Optimization Attempt 1 - Add more layers, reduce units, and change activation to Tanh.__

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="tanh", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="tanh"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation="tanh"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation="tanh"))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="tanh"))

# Sixth hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 5)                 220
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 4)                 24
#
#  dense_3 (Dense)             (None, 4)                 20
#
#  dense_4 (Dense)             (None, 3)                 15
#
#  dense_5 (Dense)             (None, 3)                 12
#
#  dense_6 (Dense)             (None, 1)                 4
#
# ...
# Total params: 325
# Trainable params: 325
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 713us/step - loss: 0.6084 - accuracy: 0.6930
# Epoch 2/50
# 804/804 [==============================] - 1s 704us/step - loss: 0.5795 - accuracy: 0.7245
# Epoch 3/50
# 804/804 [==============================] - 1s 720us/step - loss: 0.5701 - accuracy: 0.7266
# Epoch 4/50
# 804/804 [==============================] - 1s 708us/step - loss: 0.5651 - accuracy: 0.7285
# Epoch 5/50
# 804/804 [==============================] - 1s 703us/step - loss: 0.5616 - accuracy: 0.7303
# Epoch 6/50
# 804/804 [==============================] - 1s 823us/step - loss: 0.5592 - accuracy: 0.7306
# Epoch 7/50
# 804/804 [==============================] - 1s 755us/step - loss: 0.5580 - accuracy: 0.7292
# Epoch 8/50
# 804/804 [==============================] - 1s 696us/step - loss: 0.5566 - accuracy: 0.7313
# Epoch 9/50
# 804/804 [==============================] - 1s 698us/step - loss: 0.5560 - accuracy: 0.7300
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5566 - accuracy: 0.7289 - 243ms/epoch - 905us/step
# Loss: 0.556552529335022, Accuracy: 0.728863000869751

# %% [markdown]
# __Optimization Attempt 2 - Reduce the number of features by dropping columns.__

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df_dummy2 = pd.get_dummies(application_df)
df_dummy2.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
target2 = df_dummy2['IS_SUCCESSFUL']
features2 = df_dummy2.drop(columns=['IS_SUCCESSFUL','INCOME_AMT_1-9999','INCOME_AMT_10000-24999','INCOME_AMT_100000-499999','INCOME_AMT_10M-50M','INCOME_AMT_1M-5M','INCOME_AMT_25000-99999','INCOME_AMT_50M+','INCOME_AMT_5M-10M','SPECIAL_CONSIDERATIONS_N','SPECIAL_CONSIDERATIONS_Y','APPLICATION_TYPE_Other','STATUS'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features2, target2, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=31))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 80)                2560
#
#  dense_8 (Dense)             (None, 30)                2430
#
#  dense_9 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5,021
# Trainable params: 5,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 616us/step - loss: 0.5726 - accuracy: 0.7175
# Epoch 2/50
# 804/804 [==============================] - 0s 616us/step - loss: 0.5593 - accuracy: 0.7241
# Epoch 3/50
# 804/804 [==============================] - 0s 611us/step - loss: 0.5571 - accuracy: 0.7264
# Epoch 4/50
# 804/804 [==============================] - 0s 610us/step - loss: 0.5562 - accuracy: 0.7251
# Epoch 5/50
# 804/804 [==============================] - 0s 615us/step - loss: 0.5542 - accuracy: 0.7257
# Epoch 6/50
# 804/804 [==============================] - 0s 613us/step - loss: 0.5534 - accuracy: 0.7254
# Epoch 7/50
# 804/804 [==============================] - 1s 701us/step - loss: 0.5533 - accuracy: 0.7268
# Epoch 8/50
# 804/804 [==============================] - 0s 601us/step - loss: 0.5522 - accuracy: 0.7280
# Epoch 9/50
# 804/804 [==============================] - 0s 615us/step - loss: 0.5524 - accuracy: 0.7280
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5518 - accuracy: 0.7226 - 218ms/epoch - 814us/step
# Loss: 0.5518010258674622, Accuracy: 0.7225655913352966

# %% [markdown]
# __Optimization Attempt 3 - Using reduced features, add more layers and change activation to Tanh.__

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="tanh", input_dim=31))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="tanh"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation="tanh"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation="tanh"))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation="tanh"))

# Sixth hidden layer
nn.add(tf.keras.layers.Dense(units=2, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 5)                 160
#
#  dense_11 (Dense)            (None, 5)                 30
#
#  dense_12 (Dense)            (None, 4)                 24
#
#  dense_13 (Dense)            (None, 4)                 20
#
#  dense_14 (Dense)            (None, 3)                 15
#
#  dense_15 (Dense)            (None, 2)                 8
#
#  dense_16 (Dense)            (None, 1)                 3
#
# ...
# Total params: 260
# Trainable params: 260
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 698us/step - loss: 0.6126 - accuracy: 0.6976
# Epoch 2/50
# 804/804 [==============================] - 1s 818us/step - loss: 0.5831 - accuracy: 0.7254
# Epoch 3/50
# 804/804 [==============================] - 1s 682us/step - loss: 0.5809 - accuracy: 0.7259
# Epoch 4/50
# 804/804 [==============================] - 1s 696us/step - loss: 0.5770 - accuracy: 0.7249
# Epoch 5/50
# 804/804 [==============================] - 1s 692us/step - loss: 0.5689 - accuracy: 0.7256
# Epoch 6/50
# 804/804 [==============================] - 1s 776us/step - loss: 0.5649 - accuracy: 0.7261
# Epoch 7/50
# 804/804 [==============================] - 1s 692us/step - loss: 0.5627 - accuracy: 0.7255
# Epoch 8/50
# 804/804 [==============================] - 1s 693us/step - loss: 0.5615 - accuracy: 0.7259
# Epoch 9/50
# 804/804 [==============================] - 1s 685us/step - loss: 0.5602 - accuracy: 0.7262
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5581 - accuracy: 0.7213 - 237ms/epoch - 886us/step
# Loss: 0.5581039190292358, Accuracy: 0.7212827801704407

# %% [markdown]
# __Optimization Attempt 4 - Using attempt 2 model, increase Epochs.__

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=31))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 80)                2560
#
#  dense_18 (Dense)            (None, 30)                2430
#
#  dense_19 (Dense)            (None, 1)                 31
#
# ...
# Total params: 5,021
# Trainable params: 5,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=250)
# Out:
# Epoch 1/250
# 804/804 [==============================] - 1s 629us/step - loss: 0.5697 - accuracy: 0.7186
# Epoch 2/250
# 804/804 [==============================] - 0s 617us/step - loss: 0.5588 - accuracy: 0.7242
# Epoch 3/250
# 804/804 [==============================] - 0s 614us/step - loss: 0.5561 - accuracy: 0.7263
# Epoch 4/250
# 804/804 [==============================] - 0s 604us/step - loss: 0.5539 - accuracy: 0.7273
# Epoch 5/250
# 804/804 [==============================] - 0s 610us/step - loss: 0.5531 - accuracy: 0.7269
# Epoch 6/250
# 804/804 [==============================] - 0s 612us/step - loss: 0.5527 - accuracy: 0.7274
# Epoch 7/250
# 804/804 [==============================] - 0s 614us/step - loss: 0.5524 - accuracy: 0.7285
# Epoch 8/250
# 804/804 [==============================] - 1s 626us/step - loss: 0.5519 - accuracy: 0.7277
# Epoch 9/250
# 804/804 [==============================] - 0s 617us/step - loss: 0.5514 - accuracy: 0.7274
# Epoch 10/250
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5595 - accuracy: 0.7290 - 199ms/epoch - 742us/step
# Loss: 0.5595197081565857, Accuracy: 0.7289795875549316

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization.h5')
